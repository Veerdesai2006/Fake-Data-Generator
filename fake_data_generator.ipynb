# %%
# lists of fake data.
import random

first_names = ['John', 'Jane', 'Corey', 'Travis', 'Dave', 'Kurt', 'Neil', 'Sam', 'Steve', 'Tom', 'James', 'Robert', 'Michael', 'Charles', 'Joe', 'Mary', 'Maggie', 'Nicole', 'Patricia', 'Linda', 'Barbara', 'Elizabeth', 'Laura', 'Jennifer', 'Maria']

last_names = ['Smith', 'Doe', 'Jenkins', 'Robinson', 'Davis', 'Stuart', 'Jefferson', 'Jacobs', 'Wright', 'Patterson', 'Wilks', 'Arnold', 'Johnson', 'Williams', 'Jones', 'Brown', 'Davis', 'Miller', 'Wilson', 'Moore', 'Taylor', 'Anderson', 'Thomas', 'Jackson', 'White', 'Harris', 'Martin']

street_names = ['Main', 'High', 'Pearl', 'Maple', 'Park', 'Oak', 'Pine', 'Cedar', 'Elm', 'Washington', 'Lake', 'Hill']

fake_cities = ['Metropolis', 'Eerie', "King's Landing", 'Sunnydale', 'Bedrock', 'South Park', 'Atlantis', 'Mordor', 'Olympus', 'Dawnstar', 'Balmora', 'Gotham', 'Springfield', 'Quahog', 'Smalltown', 'Epicburg', 'Pythonville', 'Faketown', 'Westworld', 'Thundera', 'Vice City', 'Blackwater', 'Oldtown', 'Valyria', 'Winterfell', 'Braavos‎', 'Lakeview']

states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# %%
# code for generato
for num in range(100):
    first = random.choice(first_names)
    last = random.choice(last_names)

    phone = f'{random.randint(100, 999)}-555-{random.randint(1000,9999)}'

    street_num = random.randint(100, 999)
    street = random.choice(street_names)
    city = random.choice(fake_cities)
    state = random.choice(states)
    zip_code = random.randint(10000, 99999)
    address = f'{street_num} {street} St., {city} {state} {zip_code}'

    email = first.lower() + last.lower() + '@bogusemail.com'

    print(f'{first} {last}\n{phone}\n{address}\n{email}\n')
# Out:
# Nicole Robinson
# 379-555-2390
# 309 Main St., Mordor IL 52000
# nicolerobinson@bogusemail.com
#
# Maria White
# 685-555-4724
# 859 Main St., Smalltown LA 79999
# mariawhite@bogusemail.com
#
# Travis Johnson
# 722-555-3271
# 265 Maple St., Epicburg NM 51748
# travisjohnson@bogusemail.com
#
# James Martin
# 212-555-6585
# 561 Lake St., Blackwater NY 99020
# jamesmartin@bogusemail.com
#
# Kurt Miller
# 159-555-6392
# 283 Cedar St., Atlantis DC 48020
# kurtmiller@bogusemail.com
#
# Jane Wright
# 749-555-3521
# 422 Pine St., Springfield MA 82786
# janewright@bogusemail.com
#
# Maria Thomas
# 622-555-8293
# 658 Oak St., Faketown OR 14611
# mariathomas@bogusemail.com
#
# Tom Moore
# 443-555-8256
# 462 Pearl St., Mordor ND 86556
# tommoore@bogusemail.com
#
# Sam Miller
# 686-555-3329
# 870 Main St., Springfield NE 97033
# sammiller@bogusemail.com
#
# Maggie Wilks
# 833-555-3519
# 319 Washington St., Olympus ID 68649
# maggiewilks@bogusemail.com
#
# Linda Anderson
# 227-555-6244
# 811 Cedar St., Faketown NM 96705
# lindaanderson@bogusemail.com
#
# Sam Jones
# 754-555-4556
# 329 Oak St., Springfield WV 96673
# samjones@bogusemail.com
#
# Elizabeth Davis
# 617-555-5121
# 308 Pearl St., Sunnydale SC 86929
# Corey Arnold
# 491-555-6233
# 366 Hill St., Atlantis NE 38160
# coreyarnold@bogusemail.com
#
# John Anderson
# 242-555-3965
# 211 Park St., Metropolis MO 51741
# johnanderson@bogusemail.com
#
# Nicole Thomas
# 762-555-6588
# 165 Pearl St., South Park AL 92347
# nicolethomas@bogusemail.com
#
# Michael Wilks
# 197-555-8803
# 569 Park St., King's Landing MN 90831
# michaelwilks@bogusemail.com
#
# Jane Smith
# 462-555-1863
# 230 Oak St., Braavos‎ IN 54872
# janesmith@bogusemail.com
#
# Neil Arnold
# 186-555-9641
# 470 Cedar St., Epicburg MS 56973
# neilarnold@bogusemail.com
#
# Travis Taylor
# 730-555-5148
# 732 Pine St., Sunnydale IA 64728
# travistaylor@bogusemail.com
#
# Nicole Robinson
# 908-555-7445
# 638 Pearl St., Sunnydale TN 74661
# nicolerobinson@bogusemail.com
#
# Steve Wright
# 408-555-5438
# 608 Main St., Epicburg DE 26997
# stevewright@bogusemail.com
#
# Kurt Jackson
# 765-555-7969
# 511 Elm St., Faketown MO 65876
# kurtjackson@bogusemail.com
#
# Maggie Stuart
# 337-555-8291
# 671 Hill St., Bedrock SD 76889
# maggiestuart@bogusemail.com
#
# Sam Doe
# 479-555-8473
# 434 Hill St., Valyria IL 79642
# samdoe@bogusemail.com
#
# Charles Robinson
# 717-555-5018
# 994 Pine St., Gotham CO 57475
# charlesrobinson@bogusemail.com
#
# Maria Wilson
# 643-555-4394
# 380 Washington St., Balmora DE 26171
# mariawilson@bogusemail.com
#
# Corey Miller
# 248-555-8617
# 579 Main St., Mordor NE 35329
# coreymiller@bogusemail.com
#
# Maria Davis
# 202-555-3205
# 713 Washington St., Lakeview SD 89968
# mariadavis@bogusemail.com
#
# Kurt Arnold
# 545-555-3254
# 728 Maple St., Valyria CA 19809
# kurtarnold@bogusemail.com
#
# Kurt Wilson
# 287-555-6772
# 596 High St., Gotham AL 15551
# kurtwilson@bogusemail.com
#
# Kurt Stuart
# 294-555-2318
# 438 Cedar St., Balmora OH 49891
# kurtstuart@bogusemail.com
#
# Laura Jones
# 727-555-8809
# 729 Park St., South Park CA 13248
# laurajones@bogusemail.com
#
# Elizabeth Wright
# 940-555-2314
# 363 High St., King's Landing IL 53737
# elizabethwright@bogusemail.com
#
# Robert Stuart
# 333-555-2286
# 562 Park St., Smalltown HI 42770
# robertstuart@bogusemail.com
#
# Laura Brown
# 794-555-3472
# 729 Pine St., Winterfell SD 87853
# laurabrown@bogusemail.com
#
# Elizabeth Davis
# 966-555-2385
# 675 Washington St., Vice City NV 97882
# elizabethdavis@bogusemail.com
#
# Barbara Jones
# 987-555-3453
# 847 High St., Dawnstar WY 69148
# barbarajones@bogusemail.com
#
# Mary Davis
# 172-555-3085
# 123 Washington St., Lakeview DC 82048
# marydavis@bogusemail.com
#
# Dave Jones
# 500-555-3436
# 200 Main St., Metropolis NH 59281
# davejones@bogusemail.com
#
# Kurt Taylor
# 647-555-7883
# 761 Main St., Oldtown MT 65380
# kurttaylor@bogusemail.com
#
# John Jefferson
# 818-555-6224
# 730 Elm St., Westworld DC 85691
# johnjefferson@bogusemail.com
